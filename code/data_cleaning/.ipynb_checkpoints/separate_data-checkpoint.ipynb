# %% [markdown]
# Removing some more features to make the dataset smaller
# -> Making it easier to load and process

# %%
import pandas as pd

# %%
# spriha - time of day analysis

year_list = [i for i in range(2014, 2024)]

for year in year_list:

    print(f"Started {year}")
    
    # load data
    data = pd.read_csv(f"../../data/main_data/cleaned/Parking_Violations_Issued_{str(year)}.csv",
                       dtype="string")
    
    data2 = data[["Issue Date", "Violation Precinct", "Violation Time"]]

    # save data
    data2.to_csv(f"../../data/main_data/time_of_day/Parking_Violations_Issued_{str(year)}.csv", index=False)

    print(f"Finished {str(year)}")
# Out:
# Started 2014
# Finished 2014
# Started 2015
# Finished 2015
# Started 2016
# Finished 2016
# Started 2017
# Finished 2017
# Started 2018
# Finished 2018
# Started 2019
# Finished 2019
# Started 2020
# Finished 2020
# Started 2021
# Finished 2021
# Started 2022
# Finished 2022
# Started 2023
# Finished 2023

# %%
# divij - color and plate type analysis

year_list = [i for i in range(2014, 2024)]

for year in year_list:

    print(f"Started {year}")
    
    # load data
    data = pd.read_csv(f"../../data/main_data/cleaned/Parking_Violations_Issued_{str(year)}.csv",
                       dtype="string")
    
    data2 = data[["Issue Date", "Violation Precinct", "Vehicle Color", "Plate Type"]]

    # save data
    data2.to_csv(f"../../data/main_data/color_and_plate_type/Parking_Violations_Issued_{str(year)}.csv", index=False)

    print(f"Finished {str(year)}")
# Out:
# Started 2014
# Finished 2014
# Started 2015
# Finished 2015
# Started 2016
# Finished 2016
# Started 2017
# Finished 2017
# Started 2018
# Finished 2018
# Started 2019
# Finished 2019
# Started 2020
# Finished 2020
# Started 2021
# Finished 2021
# Started 2022
# Finished 2022
# Started 2023
# Finished 2023

# %%
data
# Out:
#       Summons Number  Issue Date Violation Time Violation Code  \
# 0         9054647449  05/25/2023          0626A             40
# 1         8892972947  01/30/2023          1255P             37
# 2         9030528436  02/13/2023          1115A             69
# 3         9017588044  11/28/2022          1108A             21
# 4         2009467929  12/23/2022          1110A             21
# ...              ...         ...            ...            ...
# 94888     8941027640  09/02/2022          1244P             21
# 94889     8885210170  07/08/2022          1028A             38
# 94890     9031235258  01/30/2023          0326P             19
# 94891     9031306228  02/03/2023          0220P             16
# 94892     2011072669  03/24/2023          1201P             21
#
#       Violation Precinct Vehicle Body Type Vehicle Color Plate Type
# 0                    110              SUBN            BK        OMT
# 1                    104              SUBN         SILVE        PAS
# ...

# %%
# data["Violation Precinct"].value_counts()
